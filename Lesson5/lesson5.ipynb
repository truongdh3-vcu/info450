# %% [markdown]
# <a href="https://colab.research.google.com/github/truongdh3-vcu/info450/blob/main/Lesson5/lesson5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url="https://raw.githubusercontent.com/truongdh3-vcu/info450/refs/heads/main/Lesson5/soccer.json"
response=requests.get(url)
response.status_code
response.raise_for_status()
data=response.json()
data.keys()
data['matches'][1]
# Out:
# {'round': 'First Stage, Group A',
#  'date': '2026-06-11',
#  'time': '20:00 UTC-6',
#  'team1': 'South Korea',
#  'team2': 'Czech Republic',
#  'score': {'ft': [2, 1], 'ht': [0, 0]},
#  'goals1': [{'name': 'HWANG Inbeom', 'minute': '67'},
#   {'name': 'OH Hyeongyu', 'minute': '80'}],
#  'goals2': [{'name': 'Ladislav KREJCI', 'minute': '59'}],
#  'ground': 'Guadalajara Stadium, Guadalajara',
#  'attendance': 44985,
#  'lineup': [{'starter': [{'name': 'KIM Seunggyu'},
#     {'name': 'LEE Hanbeom'},
#     {'name': 'KIM Minjae'},
#     {'name': 'LEE Taeseok'},
#     {'name': 'SEOL Youngwoo'},
#     {'name': 'LEE Gihyuk'},
#     {'name': 'HWANG Inbeom'},
#     {'name': 'PAIK Seungho'},
#     {'name': 'LEE Jaesung'},
#     {'name': 'LEE Kangin'},
#     {'name': 'SON Heungmin', 'captain': True}],
#    'bench': [{'name': 'EOM Jisung'},
#     {'name': 'KIM Jingyu'},
#     {'name': 'PARK Jinseob'},
#     {'name': 'HWANG Heechan'},
#     {'name': 'OH Hyeongyu'}],
# ...
